# %%
import pandas as pd
import folium

# %%
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)

seoul_map

# %%
seoul_map.save("./data/seoul.html")

# %%
df = pd.read_excel("./data/서울지역_대학교_위치.xlsx")
df.head()
# Out:
#      Unnamed: 0         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
# 대학교 리스트를 데이터프레임 변환
df = pd.read_excel('./data/서울지역_대학교_위치.xlsx', index_col=0)

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], tiles="Cartodb Positron", 
                       zoom_start=12)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df['위도'], df['경도']):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# 지도 객체 확인하기 
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_564a73f90c548a1208d24b39c1e7f5ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_564a73f90c548a1208d24b39c1e7f5ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_564a73f90c548a1208d24b39c1e7f5ab = L.map(
#                 &quot;map_564a73f90c548a1208d24b39c1e7f5ab&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea5e1c9cdd644b55e99d028247136291 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea5e1c9cdd644b55e99d028247136291.addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#             var marker_4f82fa00c66cfe9b67d61f7f6094f0ee = L.marker(
#                 [37.592573, 127.046737],
#                 {
# }
#             ).addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#         var popup_14227d78a142cde84a7d3afbfe60fcaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_691e19e74c9f92862b87d02e206e8576 = $(`&lt;div id=&quot;html_691e19e74c9f92862b87d02e206e8576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_14227d78a142cde84a7d3afbfe60fcaf.setContent(html_691e19e74c9f92862b87d02e206e8576);
#
#
#
#         marker_4f82fa00c66cfe9b67d61f7f6094f0ee.bindPopup(popup_14227d78a142cde84a7d3afbfe60fcaf)
#         ;
#
#
#
#
#             var marker_2f9d52c15c004eeed9b1a688a3245df6 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {
# }
#             ).addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#         var popup_e47b97c98515470e4852982b62c38244 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3966582e86e7d35b5ff72eb90f6722c = $(`&lt;div id=&quot;html_b3966582e86e7d35b5ff72eb90f6722c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_e47b97c98515470e4852982b62c38244.setContent(html_b3966582e86e7d35b5ff72eb90f6722c);
#
#
#
#         marker_2f9d52c15c004eeed9b1a688a3245df6.bindPopup(popup_e47b97c98515470e4852982b62c38244)
#         ;
#
#
#
#
#             var marker_ae0c3010d692caf30b9685238ef45f8d = L.marker(
#                 [37.5859218, 127.0043275],
#                 {
# }
#             ).addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#         var popup_8c92f0ccefd062d3f6e96e1de18a2267 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c898525a162d195532b41bb773c76b88 = $(`&lt;div id=&quot;html_c898525a162d195532b41bb773c76b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_8c92f0ccefd062d3f6e96e1de18a2267.setContent(html_c898525a162d195532b41bb773c76b88);
#
#
#
#         marker_ae0c3010d692caf30b9685238ef45f8d.bindPopup(popup_8c92f0ccefd062d3f6e96e1de18a2267)
#         ;
#
#
#
#
#             var marker_2d84ab374028e6d17af409b965720096 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {
# }
#             ).addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#         var popup_e9e1a399fc5ef9c9aa927bef64870648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6fdb4c8dc46ac63dc6235ee2cf07b2f = $(`&lt;div id=&quot;html_a6fdb4c8dc46ac63dc6235ee2cf07b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_e9e1a399fc5ef9c9aa927bef64870648.setContent(html_a6fdb4c8dc46ac63dc6235ee2cf07b2f);
#
#
#
#         marker_2d84ab374028e6d17af409b965720096.bindPopup(popup_e9e1a399fc5ef9c9aa927bef64870648)
#         ;
#
#
#
#
#             var marker_8240c2fdb9b20c3aab4f27aacd250f6d = L.marker(
#                 [37.5676455, 126.96161],
#                 {
# }
#             ).addTo(map_564a73f90c548a1208d24b39c1e7f5ab);
#
#
#         var popup_d86100500d5332a8f43599de6d225dc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5230ff807db7debf66a3f7a282faf73a = $(`&lt;div id=&quot;html_5230ff807db7debf66a3f7a282faf73a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_d86100500d5332a8f43599d
